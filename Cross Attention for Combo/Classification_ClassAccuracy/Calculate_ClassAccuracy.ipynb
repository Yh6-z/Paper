# %%
import pandas as pd
import os
import random

# %%
import pandas as pd
import os

CATEGORIES = [
    'Social Issues',
    'Politics & International',
    'Culture & Lifestyle',
    'Environment & Safety',
    'Science & Technology',
    'Economy & Business'
]

def split_datasets_by_category(input_file, content_file, output_dir):
    """
    加载分类结果，按类别拆分数据集。
    为每个类别生成一个CSV文件，包含属于该类别的所有test_id的headline、CTR和pred_CTR_i。
    """
    
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)
    
    # 加载完整数据集
    df = pd.read_csv(input_file)
    
    # 加载content_level_categories.csv（test_id级别类别）
    content_df = pd.read_csv(content_file)
    
    # 选择需要的列：test_id, headline, CTR, pred_CTR_1 到 pred_CTR_63
    pred_columns = [f'pred_CTR_{i}' for i in range(1, 64)]
    base_columns = ['test_id', 'headline', 'CTR'] + pred_columns
    
    # 为每个类别创建数据集
    for category in CATEGORIES:
        # 过滤属于该类别的test_id（category == 1）
        test_ids = content_df[content_df[category] == 1]['test_id'].tolist()
        
        if not test_ids:
            print(f"警告：类别 '{category}' 没有test_id，跳过。")
            continue
        
        # 从df中提取这些test_id的所有行
        category_df = df[df['test_id'].isin(test_ids)][base_columns]
        
        if category_df.empty:
            print(f"警告：类别 '{category}' 没有数据，跳过。")
            continue
        
        # 保存为CSV
        output_file = os.path.join(output_dir, f"{category}_dataset.csv")
        category_df.to_csv(output_file, index=False)
        print(f"保存类别 '{category}' 的数据集到 {output_file}，行数：{len(category_df)}")


# script_dir = os.path.dirname(os.path.abspath(__file__))
script_dir = os.getcwd()
print("当前脚本的文件夹位置为: ", script_dir)
input_file = os.path.join(script_dir, "classified_dataset.csv")
content_file = os.path.join(script_dir, "content_level_categories.csv")
output_dir = os.path.join(script_dir, "category_datasets")

# 运行函数
split_datasets_by_category(input_file = input_file, content_file = content_file, output_dir = output_dir)
# Out:
# 当前脚本的文件夹位置为:  e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy
# 保存类别 'Social Issues' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Social Issues_dataset.csv，行数：9935
# 保存类别 'Politics & International' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Politics & International_dataset.csv，行数：2759
# 保存类别 'Culture & Lifestyle' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Culture & Lifestyle_dataset.csv，行数：10253
# 保存类别 'Environment & Safety' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Environment & Safety_dataset.csv，行数：2154
# 保存类别 'Science & Technology' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Science & Technology_dataset.csv，行数：2180
# 保存类别 'Economy & Business' 的数据集到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\category_datasets\Economy & Business_dataset.csv，行数：1867

# %%
CATEGORIES = [
    'Social Issues',
    'Politics & International',
    'Culture & Lifestyle',
    'Environment & Safety',
    'Science & Technology',
    'Economy & Business'
]

def evaluate_accuracy(df):
    """
    计算准确率函数（用户提供的逻辑）。
    """
    if df.empty or "pred_CTR" not in df.columns:
        print("错误：数据集为空或缺少 pred_CTR 列，跳过准确率计算")
        return 0.0, 0.0, 0, 0, 0
    
    correct = 0
    random_correct = 0
    total = 0
    
    for test_id, group in df.groupby("test_id"):
        if len(group) == 0:
            continue
        
        max_ctr = group["CTR"].max()
        true_max_indices = group[group["CTR"] == max_ctr].index.tolist()
        
        pred_max_idx = group["pred_CTR"].idxmax()
        valid_indices = group.index.tolist()
        
        total += 1
        if pred_max_idx in true_max_indices:
            correct += 1
        
        random_idx = random.choice(valid_indices)
        if random_idx in true_max_indices:
            random_correct += 1
    
    accuracy = correct / total if total > 0 else 0.0
    random_accuracy = random_correct / total if total > 0 else 0.0
    print(f"准确率计算：正确 {correct}/{total}，准确率 {accuracy:.3f}")
    print(f"随机准确率：正确 {random_correct}/{total}，随机准确率 {random_accuracy:.3f}")
    return accuracy, random_accuracy, correct, random_correct, total

def compute_accuracy_for_category(input_dir='category_datasets', output_dir='accuracy_results', combination_file='all_combinations.csv'):
    """
    为每个类别计算63个模型的准确率，并映射到Combination，保存为CSV。
    """
    # 加载Combination映射
    try:
        combination_df = pd.read_csv(combination_file)
        # 创建pred_CTR_{i}到Combination的映射
        pred_to_combination = dict(zip(combination_df['New_Column_Name'], combination_df['Combination']))
    except FileNotFoundError:
        print(f"错误：未找到 {combination_file}，无法映射Combination")
        return
    except KeyError as e:
        print(f"错误：{combination_file} 缺少必要列 {e}")
        return
    
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)
    
    for category in CATEGORIES:
        input_file = os.path.join(input_dir, f"{category}_dataset.csv")
        if not os.path.exists(input_file):
            print(f"警告：类别 '{category}' 的数据集不存在，跳过。")
            continue
        
        df = pd.read_csv(input_file)
        
        results = []
        for i in range(1, 64):  # 63个模型
            pred_col = f'pred_CTR_{i}'
            if pred_col not in df.columns:
                print(f"警告：缺少列 {pred_col}，跳过模型 {i}")
                continue
            
            # 获取Combination名称
            combination = pred_to_combination.get(pred_col, f"Unknown_{i}")
            
            # 复制df并重命名pred列
            df_temp = df.copy()
            df_temp['pred_CTR'] = df_temp[pred_col]
            
            # 计算准确率
            accuracy, random_accuracy, correct, random_correct, total = evaluate_accuracy(df_temp)
            
            results.append({
                'Combination': combination,  # 使用Combination替换model_id
                'accuracy': accuracy,
                'random_accuracy': random_accuracy,
                'correct': correct,
                'random_correct': random_correct,
                'total': total
            })
        
        # 保存结果为CSV
        results_df = pd.DataFrame(results)
        output_file = os.path.join(output_dir, f"{category}_accuracy_different_model.csv")
        results_df.to_csv(output_file, index=False)
        print(f"保存类别 '{category}' 的准确率结果到 {output_file}")

# script_dir = os.path.dirname(os.path.abspath(__file__))
script_dir = os.getcwd()
print("当前脚本的文件夹位置为: ", script_dir)
parent_dir = os.path.dirname(script_dir)
    
input_dir = os.path.join(script_dir, "category_datasets")
combination_file = os.path.join(parent_dir, "Merge_Combo_RESULT", "all_combinations.csv")
output_dir = os.path.join(script_dir, "accuracy_results")
# 运行函数
compute_accuracy_for_category(input_dir = input_dir, output_dir = output_dir, combination_file = combination_file)
# Out:
# 当前脚本的文件夹位置为:  e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy
# 准确率计算：正确 1161/2616，准确率 0.444
# 随机准确率：正确 799/2616，随机准确率 0.305
# 准确率计算：正确 1166/2616，准确率 0.446
# 随机准确率：正确 839/2616，随机准确率 0.321
# 准确率计算：正确 1166/2616，准确率 0.446
# 随机准确率：正确 827/2616，随机准确率 0.316
# 准确率计算：正确 1151/2616，准确率 0.440
# 随机准确率：正确 813/2616，随机准确率 0.311
# 准确率计算：正确 1156/2616，准确率 0.442
# 随机准确率：正确 793/2616，随机准确率 0.303
# 准确率计算：正确 1175/2616，准确率 0.449
# 随机准确率：正确 817/2616，随机准确率 0.312
# 准确率计算：正确 1140/2616，准确率 0.436
# 随机准确率：正确 809/2616，随机准确率 0.309
# 准确率计算：正确 1145/2616，准确率 0.438
# 随机准确率：正确 851/2616，随机准确率 0.325
# 准确率计算：正确 1135/2616，准确率 0.434
# 随机准确率：正确 785/2616，随机准确率 0.300
# 准确率计算：正确 1131/2616，准确率 0.432
# 随机准确率：正确 810/2616，随机准确率 0.310
# 准确率计算：正确 1135/2616，准确率 0.434
# 随机准确率：正确 820/2616，随机准确率 0.313
# 准确率计算：正确 1161/2616，准确率 0.444
# 随机准确率：正确 787/2616，随机准确率 0.301
# 准确率计算：正确 1141/2616，准确率 0.436
# 随机准确率：正确 815/2616，随机准确率 0.312
# 准确率计算：正确 1189/2616，准确率 0.455
# 随机准确率：正确 822/2616，随机准确率 0.314
# 准确率计算：正确 1177/2616，准确率 0.450
# 随机准确率：正确 816/2616，随机准确率 0.312
# 准确率计算：正确 1160/2616，准确率 0.443
# 随机准确率：正确 769/2616，随机准确率 0.294
# 准确率计算：正确 1177/2616，准确率 0.450
# 随机准确率：正确 852/2616，随机准确率 0.326
# 准确率计算：正确 1145/2616，准确率 0.438
# 随机准确率：正确 770/2616，随机准确率 0.294
# 准确率计算：正确 1127/2616，准确率 0.431
# 随机准确率：正确 804/2616，随机准确率 0.307
# 准确率计算：正确 1159/2616，准确率 0.443
# 随机准确率：正确 825/2616，随机准确率 0.315
# 准确率计算：正确 1145/2616，准确率 0.438
# 随机准确率：正确 824/2616，随机准确率 0.315
# 准确率计算：正确 1156/2616，准确率 0.442
# 随机准确率：正确 798/2616，随机准确率 0.305
# 准确率计算：正确 1151/2616，准确率 0.440
# 随机准确率：正确 813/2616，随机准确率 0.311
# 准确率计算：正确 1143/2616，准确率 0.437
# 随机准确率：正确 783/2616，随机准确率 0.299
# 准确率计算：正确 1124/2616，准确率 0.430
# 随机准确率：正确 809/2616，随机准确率 0.309
# 准确率计算：正确 1135/2616，准确率 0.434
# 随机准确率：正确 821/2616，随机准确率 0.314
# 准确率计算：正确 1149/2616，准确率 0.439
# 随机准确率：正确 822/2616，随机准确率 0.314
# 准确率计算：正确 1143/2616，准确率 0.437
# 随机准确率：正确 816/2616，随机准确率 0.312
# 准确率计算：正确 1153/2616，准确率 0.441
# 随机准确率：正确 857/2616，随机准确率 0.328
# 准确率计算：正确 1182/2616，准确率 0.452
# 随机准确率：正确 824/2616，随机准确率 0.315
# 准确率计算：正确 1143/2616，准确率 0.437
# 随机准确率：正确 806/2616，随机准确率 0.308
# 准确率计算：正确 1165/2616，准确率 0.445
# 随机准确率：正确 805/2616，随机准确率 0.308
# 准确率计算：正确 1130/2616，准确率 0.432
# 随机准确率：正确 831/2616，随机准确率 0.318
# 准确率计算：正确 1150/2616，准确率 0.440
# 随机准确率：正确 823/2616，随机准确率 0.315
# 准确率计算：正确 1158/2616，准确率 0.443
# 随机准确率：正确 836/2616，随机准确率 0.320
# 准确率计算：正确 1181/2616，准确率 0.451
# 随机准确率：正确 822/2616，随机准确率 0.314
# 准确率计算：正确 1142/2616，准确率 0.437
# 随机准确率：正确 829/2616，随机准确率 0.317
# 准确率计算：正确 1142/2616，准确率 0.437
# 随机准确率：正确 791/2616，随机准确率 0.302
# 准确率计算：正确 1163/2616，准确率 0.445
# 随机准确率：正确 823/2616，随机准确率 0.315
# 准确率计算：正确 1162/2616，准确率 0.444
# 随机准确率：正确 809/2616，随机准确率 0.309
# 准确率计算：正确 1138/2616，准确率 0.435
# 随机准确率：正确 817/2616，随机准确率 0.312
# 准确率计算：正确 1149/2616，准确率 0.439
# 随机准确率：正确 807/2616，随机准确率 0.308
# 准确率计算：正确 1125/2616，准确率 0.430
# 随机准确率：正确 834/2616，随机准确率 0.319
# 准确率计算：正确 1126/2616，准确率 0.430
# 随机准确率：正确 808/2616，随机准确率 0.309
# 准确率计算：正确 1145/2616，准确率 0.438
# 随机准确率：正确 849/2616，随机准确率 0.325
# 准确率计算：正确 1142/2616，准确率 0.437
# 随机准确率：正确 803/2616，随机准确率 0.307
# 准确率计算：正确 1156/2616，准确率 0.442
# 随机准确率：正确 817/2616，随机准确率 0.312
# 准确率计算：正确 1127/2616，准确率 0.431
# 随机准确率：正确 809/2616，随机准确率 0.309
# 准确率计算：正确 1153/2616，准确率 0.441
# 随机准确率：正确 810/2616，随机准确率 0.310
# 准确率计算：正确 1182/2616，准确率 0.452
# 随机准确率：正确 810/2616，随机准确率 0.310
# 准确率计算：正确 1163/2616，准确率 0.445
# 随机准确率：正确 822/2616，随机准确率 0.314
# 准确率计算：正确 1175/2616，准确率 0.449
# 随机准确率：正确 834/2616，随机准确率 0.319
# 准确率计算：正确 1157/2616，准确率 0.442
# 随机准确率：正确 804/2616，随机准确率 0.307
# 准确率计算：正确 1119/2616，准确率 0.428
# 随机准确率：正确 787/2616，随机准确率 0.301
# 准确率计算：正确 1164/2616，准确率 0.445
# 随机准确率：正确 821/2616，随机准确率 0.314
# 准确率计算：正确 1169/2616，准确率 0.447
# 随机准确率：正确 855/2616，随机准确率 0.327
# 准确率计算：正确 1148/2616，准确率 0.439
# 随机准确率：正确 775/2616，随机准确率 0.296
# 准确率计算：正确 1142/2616，准确率 0.437
# 随机准确率：正确 818/2616，随机准确率 0.313
# 准确率计算：正确 1133/2616，准确率 0.433
# 随机准确率：正确 852/2616，随机准确率 0.326
# 准确率计算：正确 1143/2616，准确率 0.437
# 随机准确率：正确 799/2616，随机准确率 0.305
# 准确率计算：正确 1149/2616，准确率 0.439
# 随机准确率：正确 841/2616，随机准确率 0.321
# 准确率计算：正确 1147/2616，准确率 0.438
# 随机准确率：正确 797/2616，随机准确率 0.305
# 准确率计算：正确 1159/2616，准确率 0.443
# 随机准确率：正确 853/2616，随机准确率 0.326
# 保存类别 'Social Issues' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Social Issues_accuracy_different_model.csv
# 准确率计算：正确 302/726，准确率 0.416
# 随机准确率：正确 229/726，随机准确率 0.315
# 准确率计算：正确 303/726，准确率 0.417
# 随机准确率：正确 229/726，随机准确率 0.315
# 准确率计算：正确 302/726，准确率 0.416
# 随机准确率：正确 223/726，随机准确率 0.307
# 准确率计算：正确 297/726，准确率 0.409
# 随机准确率：正确 237/726，随机准确率 0.326
# 准确率计算：正确 299/726，准确率 0.412
# 随机准确率：正确 233/726，随机准确率 0.321
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 214/726，随机准确率 0.295
# 准确率计算：正确 302/726，准确率 0.416
# 随机准确率：正确 229/726，随机准确率 0.315
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 228/726，随机准确率 0.314
# 准确率计算：正确 293/726，准确率 0.404
# 随机准确率：正确 234/726，随机准确率 0.322
# 准确率计算：正确 299/726，准确率 0.412
# 随机准确率：正确 221/726，随机准确率 0.304
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 230/726，随机准确率 0.317
# 准确率计算：正确 311/726，准确率 0.428
# 随机准确率：正确 215/726，随机准确率 0.296
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 206/726，随机准确率 0.284
# 准确率计算：正确 327/726，准确率 0.450
# 随机准确率：正确 233/726，随机准确率 0.321
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 218/726，随机准确率 0.300
# 准确率计算：正确 305/726，准确率 0.420
# 随机准确率：正确 227/726，随机准确率 0.313
# 准确率计算：正确 318/726，准确率 0.438
# 随机准确率：正确 218/726，随机准确率 0.300
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 219/726，随机准确率 0.302
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 236/726，随机准确率 0.325
# 准确率计算：正确 307/726，准确率 0.423
# 随机准确率：正确 220/726，随机准确率 0.303
# 准确率计算：正确 315/726，准确率 0.434
# 随机准确率：正确 250/726，随机准确率 0.344
# 准确率计算：正确 298/726，准确率 0.410
# 随机准确率：正确 232/726，随机准确率 0.320
# 准确率计算：正确 313/726，准确率 0.431
# 随机准确率：正确 221/726，随机准确率 0.304
# 准确率计算：正确 292/726，准确率 0.402
# 随机准确率：正确 236/726，随机准确率 0.325
# 准确率计算：正确 321/726，准确率 0.442
# 随机准确率：正确 227/726，随机准确率 0.313
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 217/726，随机准确率 0.299
# 准确率计算：正确 305/726，准确率 0.420
# 随机准确率：正确 227/726，随机准确率 0.313
# 准确率计算：正确 307/726，准确率 0.423
# 随机准确率：正确 248/726，随机准确率 0.342
# 准确率计算：正确 316/726，准确率 0.435
# 随机准确率：正确 228/726，随机准确率 0.314
# 准确率计算：正确 308/726，准确率 0.424
# 随机准确率：正确 234/726，随机准确率 0.322
# 准确率计算：正确 294/726，准确率 0.405
# 随机准确率：正确 206/726，随机准确率 0.284
# 准确率计算：正确 313/726，准确率 0.431
# 随机准确率：正确 235/726，随机准确率 0.324
# 准确率计算：正确 305/726，准确率 0.420
# 随机准确率：正确 232/726，随机准确率 0.320
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 221/726，随机准确率 0.304
# 准确率计算：正确 307/726，准确率 0.423
# 随机准确率：正确 241/726，随机准确率 0.332
# 准确率计算：正确 311/726，准确率 0.428
# 随机准确率：正确 233/726，随机准确率 0.321
# 准确率计算：正确 298/726，准确率 0.410
# 随机准确率：正确 240/726，随机准确率 0.331
# 准确率计算：正确 304/726，准确率 0.419
# 随机准确率：正确 230/726，随机准确率 0.317
# 准确率计算：正确 314/726，准确率 0.433
# 随机准确率：正确 235/726，随机准确率 0.324
# 准确率计算：正确 299/726，准确率 0.412
# 随机准确率：正确 221/726，随机准确率 0.304
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 228/726，随机准确率 0.314
# 准确率计算：正确 292/726，准确率 0.402
# 随机准确率：正确 208/726，随机准确率 0.287
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 224/726，随机准确率 0.309
# 准确率计算：正确 304/726，准确率 0.419
# 随机准确率：正确 218/726，随机准确率 0.300
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 216/726，随机准确率 0.298
# 准确率计算：正确 310/726，准确率 0.427
# 随机准确率：正确 202/726，随机准确率 0.278
# 准确率计算：正确 315/726，准确率 0.434
# 随机准确率：正确 249/726，随机准确率 0.343
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 212/726，随机准确率 0.292
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 223/726，随机准确率 0.307
# 准确率计算：正确 313/726，准确率 0.431
# 随机准确率：正确 204/726，随机准确率 0.281
# 准确率计算：正确 294/726，准确率 0.405
# 随机准确率：正确 224/726，随机准确率 0.309
# 准确率计算：正确 316/726，准确率 0.435
# 随机准确率：正确 225/726，随机准确率 0.310
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 216/726，随机准确率 0.298
# 准确率计算：正确 305/726，准确率 0.420
# 随机准确率：正确 240/726，随机准确率 0.331
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 196/726，随机准确率 0.270
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 228/726，随机准确率 0.314
# 准确率计算：正确 293/726，准确率 0.404
# 随机准确率：正确 257/726，随机准确率 0.354
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 214/726，随机准确率 0.295
# 准确率计算：正确 306/726，准确率 0.421
# 随机准确率：正确 205/726，随机准确率 0.282
# 准确率计算：正确 300/726，准确率 0.413
# 随机准确率：正确 224/726，随机准确率 0.309
# 准确率计算：正确 313/726，准确率 0.431
# 随机准确率：正确 200/726，随机准确率 0.275
# 准确率计算：正确 309/726，准确率 0.426
# 随机准确率：正确 228/726，随机准确率 0.314
# 准确率计算：正确 303/726，准确率 0.417
# 随机准确率：正确 227/726，随机准确率 0.313
# 保存类别 'Politics & International' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Politics & International_accuracy_different_model.csv
# 准确率计算：正确 1213/2715，准确率 0.447
# 随机准确率：正确 863/2715，随机准确率 0.318
# 准确率计算：正确 1227/2715，准确率 0.452
# 随机准确率：正确 880/2715，随机准确率 0.324
# 准确率计算：正确 1217/2715，准确率 0.448
# 随机准确率：正确 820/2715，随机准确率 0.302
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 876/2715，随机准确率 0.323
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 866/2715，随机准确率 0.319
# 准确率计算：正确 1227/2715，准确率 0.452
# 随机准确率：正确 858/2715，随机准确率 0.316
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 846/2715，随机准确率 0.312
# 准确率计算：正确 1194/2715，准确率 0.440
# 随机准确率：正确 831/2715，随机准确率 0.306
# 准确率计算：正确 1207/2715，准确率 0.445
# 随机准确率：正确 871/2715，随机准确率 0.321
# 准确率计算：正确 1183/2715，准确率 0.436
# 随机准确率：正确 900/2715，随机准确率 0.331
# 准确率计算：正确 1191/2715，准确率 0.439
# 随机准确率：正确 851/2715，随机准确率 0.313
# 准确率计算：正确 1218/2715，准确率 0.449
# 随机准确率：正确 881/2715，随机准确率 0.324
# 准确率计算：正确 1193/2715，准确率 0.439
# 随机准确率：正确 880/2715，随机准确率 0.324
# 准确率计算：正确 1252/2715，准确率 0.461
# 随机准确率：正确 866/2715，随机准确率 0.319
# 准确率计算：正确 1218/2715，准确率 0.449
# 随机准确率：正确 909/2715，随机准确率 0.335
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 861/2715，随机准确率 0.317
# 准确率计算：正确 1239/2715，准确率 0.456
# 随机准确率：正确 861/2715，随机准确率 0.317
# 准确率计算：正确 1207/2715，准确率 0.445
# 随机准确率：正确 868/2715，随机准确率 0.320
# 准确率计算：正确 1185/2715，准确率 0.436
# 随机准确率：正确 875/2715，随机准确率 0.322
# 准确率计算：正确 1216/2715，准确率 0.448
# 随机准确率：正确 847/2715，随机准确率 0.312
# 准确率计算：正确 1193/2715，准确率 0.439
# 随机准确率：正确 873/2715，随机准确率 0.322
# 准确率计算：正确 1233/2715，准确率 0.454
# 随机准确率：正确 891/2715，随机准确率 0.328
# 准确率计算：正确 1198/2715，准确率 0.441
# 随机准确率：正确 862/2715，随机准确率 0.317
# 准确率计算：正确 1211/2715，准确率 0.446
# 随机准确率：正确 855/2715，随机准确率 0.315
# 准确率计算：正确 1177/2715，准确率 0.434
# 随机准确率：正确 912/2715，随机准确率 0.336
# 准确率计算：正确 1201/2715，准确率 0.442
# 随机准确率：正确 866/2715，随机准确率 0.319
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 857/2715，随机准确率 0.316
# 准确率计算：正确 1186/2715，准确率 0.437
# 随机准确率：正确 866/2715，随机准确率 0.319
# 准确率计算：正确 1219/2715，准确率 0.449
# 随机准确率：正确 854/2715，随机准确率 0.315
# 准确率计算：正确 1229/2715，准确率 0.453
# 随机准确率：正确 851/2715，随机准确率 0.313
# 准确率计算：正确 1206/2715，准确率 0.444
# 随机准确率：正确 898/2715，随机准确率 0.331
# 准确率计算：正确 1224/2715，准确率 0.451
# 随机准确率：正确 900/2715，随机准确率 0.331
# 准确率计算：正确 1206/2715，准确率 0.444
# 随机准确率：正确 875/2715，随机准确率 0.322
# 准确率计算：正确 1224/2715，准确率 0.451
# 随机准确率：正确 842/2715，随机准确率 0.310
# 准确率计算：正确 1203/2715，准确率 0.443
# 随机准确率：正确 913/2715，随机准确率 0.336
# 准确率计算：正确 1222/2715，准确率 0.450
# 随机准确率：正确 861/2715，随机准确率 0.317
# 准确率计算：正确 1200/2715，准确率 0.442
# 随机准确率：正确 827/2715，随机准确率 0.305
# 准确率计算：正确 1203/2715，准确率 0.443
# 随机准确率：正确 871/2715，随机准确率 0.321
# 准确率计算：正确 1212/2715，准确率 0.446
# 随机准确率：正确 859/2715，随机准确率 0.316
# 准确率计算：正确 1225/2715，准确率 0.451
# 随机准确率：正确 879/2715，随机准确率 0.324
# 准确率计算：正确 1198/2715，准确率 0.441
# 随机准确率：正确 843/2715，随机准确率 0.310
# 准确率计算：正确 1224/2715，准确率 0.451
# 随机准确率：正确 850/2715，随机准确率 0.313
# 准确率计算：正确 1177/2715，准确率 0.434
# 随机准确率：正确 827/2715，随机准确率 0.305
# 准确率计算：正确 1196/2715，准确率 0.441
# 随机准确率：正确 839/2715，随机准确率 0.309
# 准确率计算：正确 1187/2715，准确率 0.437
# 随机准确率：正确 872/2715，随机准确率 0.321
# 准确率计算：正确 1203/2715，准确率 0.443
# 随机准确率：正确 849/2715，随机准确率 0.313
# 准确率计算：正确 1226/2715，准确率 0.452
# 随机准确率：正确 903/2715，随机准确率 0.333
# 准确率计算：正确 1165/2715，准确率 0.429
# 随机准确率：正确 871/2715，随机准确率 0.321
# 准确率计算：正确 1220/2715，准确率 0.449
# 随机准确率：正确 863/2715，随机准确率 0.318
# 准确率计算：正确 1236/2715，准确率 0.455
# 随机准确率：正确 882/2715，随机准确率 0.325
# 准确率计算：正确 1228/2715，准确率 0.452
# 随机准确率：正确 894/2715，随机准确率 0.329
# 准确率计算：正确 1230/2715，准确率 0.453
# 随机准确率：正确 841/2715，随机准确率 0.310
# 准确率计算：正确 1217/2715，准确率 0.448
# 随机准确率：正确 900/2715，随机准确率 0.331
# 准确率计算：正确 1186/2715，准确率 0.437
# 随机准确率：正确 828/2715，随机准确率 0.305
# 准确率计算：正确 1216/2715，准确率 0.448
# 随机准确率：正确 857/2715，随机准确率 0.316
# 准确率计算：正确 1217/2715，准确率 0.448
# 随机准确率：正确 879/2715，随机准确率 0.324
# 准确率计算：正确 1226/2715，准确率 0.452
# 随机准确率：正确 855/2715，随机准确率 0.315
# 准确率计算：正确 1196/2715，准确率 0.441
# 随机准确率：正确 876/2715，随机准确率 0.323
# 准确率计算：正确 1188/2715，准确率 0.438
# 随机准确率：正确 867/2715，随机准确率 0.319
# 准确率计算：正确 1187/2715，准确率 0.437
# 随机准确率：正确 894/2715，随机准确率 0.329
# 准确率计算：正确 1215/2715，准确率 0.448
# 随机准确率：正确 895/2715，随机准确率 0.330
# 准确率计算：正确 1194/2715，准确率 0.440
# 随机准确率：正确 897/2715，随机准确率 0.330
# 准确率计算：正确 1231/2715，准确率 0.453
# 随机准确率：正确 885/2715，随机准确率 0.326
# 保存类别 'Culture & Lifestyle' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Culture & Lifestyle_accuracy_different_model.csv
# 准确率计算：正确 206/545，准确率 0.378
# 随机准确率：正确 156/545，随机准确率 0.286
# 准确率计算：正确 200/545，准确率 0.367
# 随机准确率：正确 158/545，随机准确率 0.290
# 准确率计算：正确 206/545，准确率 0.378
# 随机准确率：正确 165/545，随机准确率 0.303
# 准确率计算：正确 202/545，准确率 0.371
# 随机准确率：正确 153/545，随机准确率 0.281
# 准确率计算：正确 202/545，准确率 0.371
# 随机准确率：正确 160/545，随机准确率 0.294
# 准确率计算：正确 206/545，准确率 0.378
# 随机准确率：正确 168/545，随机准确率 0.308
# 准确率计算：正确 225/545，准确率 0.413
# 随机准确率：正确 161/545，随机准确率 0.295
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 179/545，随机准确率 0.328
# 准确率计算：正确 195/545，准确率 0.358
# 随机准确率：正确 162/545，随机准确率 0.297
# 准确率计算：正确 210/545，准确率 0.385
# 随机准确率：正确 164/545，随机准确率 0.301
# 准确率计算：正确 220/545，准确率 0.404
# 随机准确率：正确 144/545，随机准确率 0.264
# 准确率计算：正确 224/545，准确率 0.411
# 随机准确率：正确 178/545，随机准确率 0.327
# 准确率计算：正确 208/545，准确率 0.382
# 随机准确率：正确 140/545，随机准确率 0.257
# 准确率计算：正确 204/545，准确率 0.374
# 随机准确率：正确 145/545，随机准确率 0.266
# 准确率计算：正确 215/545，准确率 0.394
# 随机准确率：正确 162/545，随机准确率 0.297
# 准确率计算：正确 209/545，准确率 0.383
# 随机准确率：正确 162/545，随机准确率 0.297
# 准确率计算：正确 221/545，准确率 0.406
# 随机准确率：正确 162/545，随机准确率 0.297
# 准确率计算：正确 209/545，准确率 0.383
# 随机准确率：正确 150/545，随机准确率 0.275
# 准确率计算：正确 212/545，准确率 0.389
# 随机准确率：正确 167/545，随机准确率 0.306
# 准确率计算：正确 201/545，准确率 0.369
# 随机准确率：正确 153/545，随机准确率 0.281
# 准确率计算：正确 209/545，准确率 0.383
# 随机准确率：正确 145/545，随机准确率 0.266
# 准确率计算：正确 225/545，准确率 0.413
# 随机准确率：正确 149/545，随机准确率 0.273
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 150/545，随机准确率 0.275
# 准确率计算：正确 201/545，准确率 0.369
# 随机准确率：正确 141/545，随机准确率 0.259
# 准确率计算：正确 203/545，准确率 0.372
# 随机准确率：正确 179/545，随机准确率 0.328
# 准确率计算：正确 207/545，准确率 0.380
# 随机准确率：正确 165/545，随机准确率 0.303
# 准确率计算：正确 217/545，准确率 0.398
# 随机准确率：正确 150/545，随机准确率 0.275
# 准确率计算：正确 222/545，准确率 0.407
# 随机准确率：正确 186/545，随机准确率 0.341
# 准确率计算：正确 200/545，准确率 0.367
# 随机准确率：正确 173/545，随机准确率 0.317
# 准确率计算：正确 216/545，准确率 0.396
# 随机准确率：正确 148/545，随机准确率 0.272
# 准确率计算：正确 208/545，准确率 0.382
# 随机准确率：正确 151/545，随机准确率 0.277
# 准确率计算：正确 215/545，准确率 0.394
# 随机准确率：正确 145/545，随机准确率 0.266
# 准确率计算：正确 214/545，准确率 0.393
# 随机准确率：正确 178/545，随机准确率 0.327
# 准确率计算：正确 213/545，准确率 0.391
# 随机准确率：正确 153/545，随机准确率 0.281
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 181/545，随机准确率 0.332
# 准确率计算：正确 214/545，准确率 0.393
# 随机准确率：正确 157/545，随机准确率 0.288
# 准确率计算：正确 207/545，准确率 0.380
# 随机准确率：正确 160/545，随机准确率 0.294
# 准确率计算：正确 215/545，准确率 0.394
# 随机准确率：正确 149/545，随机准确率 0.273
# 准确率计算：正确 205/545，准确率 0.376
# 随机准确率：正确 171/545，随机准确率 0.314
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 138/545，随机准确率 0.253
# 准确率计算：正确 217/545，准确率 0.398
# 随机准确率：正确 157/545，随机准确率 0.288
# 准确率计算：正确 213/545，准确率 0.391
# 随机准确率：正确 165/545，随机准确率 0.303
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 153/545，随机准确率 0.281
# 准确率计算：正确 204/545，准确率 0.374
# 随机准确率：正确 153/545，随机准确率 0.281
# 准确率计算：正确 214/545，准确率 0.393
# 随机准确率：正确 152/545，随机准确率 0.279
# 准确率计算：正确 218/545，准确率 0.400
# 随机准确率：正确 158/545，随机准确率 0.290
# 准确率计算：正确 213/545，准确率 0.391
# 随机准确率：正确 160/545，随机准确率 0.294
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 150/545，随机准确率 0.275
# 准确率计算：正确 207/545，准确率 0.380
# 随机准确率：正确 163/545，随机准确率 0.299
# 准确率计算：正确 223/545，准确率 0.409
# 随机准确率：正确 150/545，随机准确率 0.275
# 准确率计算：正确 210/545，准确率 0.385
# 随机准确率：正确 171/545，随机准确率 0.314
# 准确率计算：正确 214/545，准确率 0.393
# 随机准确率：正确 173/545，随机准确率 0.317
# 准确率计算：正确 214/545，准确率 0.393
# 随机准确率：正确 151/545，随机准确率 0.277
# 准确率计算：正确 203/545，准确率 0.372
# 随机准确率：正确 168/545，随机准确率 0.308
# 准确率计算：正确 202/545，准确率 0.371
# 随机准确率：正确 146/545，随机准确率 0.268
# 准确率计算：正确 219/545，准确率 0.402
# 随机准确率：正确 145/545，随机准确率 0.266
# 准确率计算：正确 218/545，准确率 0.400
# 随机准确率：正确 144/545，随机准确率 0.264
# 准确率计算：正确 211/545，准确率 0.387
# 随机准确率：正确 154/545，随机准确率 0.283
# 准确率计算：正确 200/545，准确率 0.367
# 随机准确率：正确 159/545，随机准确率 0.292
# 准确率计算：正确 219/545，准确率 0.402
# 随机准确率：正确 162/545，随机准确率 0.297
# 准确率计算：正确 218/545，准确率 0.400
# 随机准确率：正确 167/545，随机准确率 0.306
# 准确率计算：正确 218/545，准确率 0.400
# 随机准确率：正确 144/545，随机准确率 0.264
# 准确率计算：正确 224/545，准确率 0.411
# 随机准确率：正确 161/545，随机准确率 0.295
# 保存类别 'Environment & Safety' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Environment & Safety_accuracy_different_model.csv
# 准确率计算：正确 212/552，准确率 0.384
# 随机准确率：正确 161/552，随机准确率 0.292
# 准确率计算：正确 216/552，准确率 0.391
# 随机准确率：正确 175/552，随机准确率 0.317
# 准确率计算：正确 213/552，准确率 0.386
# 随机准确率：正确 153/552，随机准确率 0.277
# 准确率计算：正确 222/552，准确率 0.402
# 随机准确率：正确 154/552，随机准确率 0.279
# 准确率计算：正确 213/552，准确率 0.386
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 215/552，准确率 0.389
# 随机准确率：正确 145/552，随机准确率 0.263
# 准确率计算：正确 233/552，准确率 0.422
# 随机准确率：正确 167/552，随机准确率 0.303
# 准确率计算：正确 217/552，准确率 0.393
# 随机准确率：正确 157/552，随机准确率 0.284
# 准确率计算：正确 225/552，准确率 0.408
# 随机准确率：正确 163/552，随机准确率 0.295
# 准确率计算：正确 219/552，准确率 0.397
# 随机准确率：正确 171/552，随机准确率 0.310
# 准确率计算：正确 221/552，准确率 0.400
# 随机准确率：正确 165/552，随机准确率 0.299
# 准确率计算：正确 229/552，准确率 0.415
# 随机准确率：正确 167/552，随机准确率 0.303
# 准确率计算：正确 222/552，准确率 0.402
# 随机准确率：正确 163/552，随机准确率 0.295
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 174/552，随机准确率 0.315
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 175/552，随机准确率 0.317
# 准确率计算：正确 226/552，准确率 0.409
# 随机准确率：正确 151/552，随机准确率 0.274
# 准确率计算：正确 238/552，准确率 0.431
# 随机准确率：正确 175/552，随机准确率 0.317
# 准确率计算：正确 217/552，准确率 0.393
# 随机准确率：正确 162/552，随机准确率 0.293
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 165/552，随机准确率 0.299
# 准确率计算：正确 219/552，准确率 0.397
# 随机准确率：正确 169/552，随机准确率 0.306
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 163/552，随机准确率 0.295
# 准确率计算：正确 233/552，准确率 0.422
# 随机准确率：正确 183/552，随机准确率 0.332
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 216/552，准确率 0.391
# 随机准确率：正确 161/552，随机准确率 0.292
# 准确率计算：正确 220/552，准确率 0.399
# 随机准确率：正确 165/552，随机准确率 0.299
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 162/552，随机准确率 0.293
# 准确率计算：正确 227/552，准确率 0.411
# 随机准确率：正确 179/552，随机准确率 0.324
# 准确率计算：正确 211/552，准确率 0.382
# 随机准确率：正确 164/552，随机准确率 0.297
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 183/552，随机准确率 0.332
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 161/552，随机准确率 0.292
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 149/552，随机准确率 0.270
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 167/552，随机准确率 0.303
# 准确率计算：正确 221/552，准确率 0.400
# 随机准确率：正确 166/552，随机准确率 0.301
# 准确率计算：正确 228/552，准确率 0.413
# 随机准确率：正确 158/552，随机准确率 0.286
# 准确率计算：正确 232/552，准确率 0.420
# 随机准确率：正确 196/552，随机准确率 0.355
# 准确率计算：正确 225/552，准确率 0.408
# 随机准确率：正确 159/552，随机准确率 0.288
# 准确率计算：正确 212/552，准确率 0.384
# 随机准确率：正确 171/552，随机准确率 0.310
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 172/552，随机准确率 0.312
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 162/552，随机准确率 0.293
# 准确率计算：正确 213/552，准确率 0.386
# 随机准确率：正确 151/552，随机准确率 0.274
# 准确率计算：正确 222/552，准确率 0.402
# 随机准确率：正确 161/552，随机准确率 0.292
# 准确率计算：正确 228/552，准确率 0.413
# 随机准确率：正确 173/552，随机准确率 0.313
# 准确率计算：正确 214/552，准确率 0.388
# 随机准确率：正确 165/552，随机准确率 0.299
# 准确率计算：正确 214/552，准确率 0.388
# 随机准确率：正确 175/552，随机准确率 0.317
# 准确率计算：正确 219/552，准确率 0.397
# 随机准确率：正确 183/552，随机准确率 0.332
# 准确率计算：正确 227/552，准确率 0.411
# 随机准确率：正确 157/552，随机准确率 0.284
# 准确率计算：正确 239/552，准确率 0.433
# 随机准确率：正确 159/552，随机准确率 0.288
# 准确率计算：正确 208/552，准确率 0.377
# 随机准确率：正确 165/552，随机准确率 0.299
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 169/552，随机准确率 0.306
# 准确率计算：正确 226/552，准确率 0.409
# 随机准确率：正确 155/552，随机准确率 0.281
# 准确率计算：正确 225/552，准确率 0.408
# 随机准确率：正确 175/552，随机准确率 0.317
# 准确率计算：正确 225/552，准确率 0.408
# 随机准确率：正确 163/552，随机准确率 0.295
# 准确率计算：正确 220/552，准确率 0.399
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 184/552，随机准确率 0.333
# 准确率计算：正确 226/552，准确率 0.409
# 随机准确率：正确 160/552，随机准确率 0.290
# 准确率计算：正确 221/552，准确率 0.400
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 234/552，准确率 0.424
# 随机准确率：正确 172/552，随机准确率 0.312
# 准确率计算：正确 215/552，准确率 0.389
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 223/552，准确率 0.404
# 随机准确率：正确 152/552，随机准确率 0.275
# 准确率计算：正确 221/552，准确率 0.400
# 随机准确率：正确 170/552，随机准确率 0.308
# 准确率计算：正确 224/552，准确率 0.406
# 随机准确率：正确 166/552，随机准确率 0.301
# 准确率计算：正确 232/552，准确率 0.420
# 随机准确率：正确 179/552，随机准确率 0.324
# 准确率计算：正确 235/552，准确率 0.426
# 随机准确率：正确 171/552，随机准确率 0.310
# 保存类别 'Science & Technology' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Science & Technology_accuracy_different_model.csv
# 准确率计算：正确 221/488，准确率 0.453
# 随机准确率：正确 153/488，随机准确率 0.314
# 准确率计算：正确 216/488，准确率 0.443
# 随机准确率：正确 141/488，随机准确率 0.289
# 准确率计算：正确 227/488，准确率 0.465
# 随机准确率：正确 144/488，随机准确率 0.295
# 准确率计算：正确 212/488，准确率 0.434
# 随机准确率：正确 146/488，随机准确率 0.299
# 准确率计算：正确 223/488，准确率 0.457
# 随机准确率：正确 143/488，随机准确率 0.293
# 准确率计算：正确 216/488，准确率 0.443
# 随机准确率：正确 151/488，随机准确率 0.309
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 144/488，随机准确率 0.295
# 准确率计算：正确 226/488，准确率 0.463
# 随机准确率：正确 155/488，随机准确率 0.318
# 准确率计算：正确 232/488，准确率 0.475
# 随机准确率：正确 157/488，随机准确率 0.322
# 准确率计算：正确 192/488，准确率 0.393
# 随机准确率：正确 144/488，随机准确率 0.295
# 准确率计算：正确 230/488，准确率 0.471
# 随机准确率：正确 159/488，随机准确率 0.326
# 准确率计算：正确 222/488，准确率 0.455
# 随机准确率：正确 141/488，随机准确率 0.289
# 准确率计算：正确 208/488，准确率 0.426
# 随机准确率：正确 142/488，随机准确率 0.291
# 准确率计算：正确 230/488，准确率 0.471
# 随机准确率：正确 140/488，随机准确率 0.287
# 准确率计算：正确 222/488，准确率 0.455
# 随机准确率：正确 151/488，随机准确率 0.309
# 准确率计算：正确 225/488，准确率 0.461
# 随机准确率：正确 148/488，随机准确率 0.303
# 准确率计算：正确 235/488，准确率 0.482
# 随机准确率：正确 144/488，随机准确率 0.295
# 准确率计算：正确 230/488，准确率 0.471
# 随机准确率：正确 156/488，随机准确率 0.320
# 准确率计算：正确 204/488，准确率 0.418
# 随机准确率：正确 132/488，随机准确率 0.270
# 准确率计算：正确 214/488，准确率 0.439
# 随机准确率：正确 143/488，随机准确率 0.293
# 准确率计算：正确 219/488，准确率 0.449
# 随机准确率：正确 154/488，随机准确率 0.316
# 准确率计算：正确 215/488，准确率 0.441
# 随机准确率：正确 137/488，随机准确率 0.281
# 准确率计算：正确 226/488，准确率 0.463
# 随机准确率：正确 138/488，随机准确率 0.283
# 准确率计算：正确 233/488，准确率 0.477
# 随机准确率：正确 155/488，随机准确率 0.318
# 准确率计算：正确 212/488，准确率 0.434
# 随机准确率：正确 156/488，随机准确率 0.320
# 准确率计算：正确 233/488，准确率 0.477
# 随机准确率：正确 145/488，随机准确率 0.297
# 准确率计算：正确 219/488，准确率 0.449
# 随机准确率：正确 135/488，随机准确率 0.277
# 准确率计算：正确 227/488，准确率 0.465
# 随机准确率：正确 159/488，随机准确率 0.326
# 准确率计算：正确 231/488，准确率 0.473
# 随机准确率：正确 150/488，随机准确率 0.307
# 准确率计算：正确 219/488，准确率 0.449
# 随机准确率：正确 137/488，随机准确率 0.281
# 准确率计算：正确 231/488，准确率 0.473
# 随机准确率：正确 140/488，随机准确率 0.287
# 准确率计算：正确 229/488，准确率 0.469
# 随机准确率：正确 154/488，随机准确率 0.316
# 准确率计算：正确 226/488，准确率 0.463
# 随机准确率：正确 158/488，随机准确率 0.324
# 准确率计算：正确 215/488，准确率 0.441
# 随机准确率：正确 136/488，随机准确率 0.279
# 准确率计算：正确 215/488，准确率 0.441
# 随机准确率：正确 152/488，随机准确率 0.311
# 准确率计算：正确 223/488，准确率 0.457
# 随机准确率：正确 146/488，随机准确率 0.299
# 准确率计算：正确 216/488，准确率 0.443
# 随机准确率：正确 146/488，随机准确率 0.299
# 准确率计算：正确 208/488，准确率 0.426
# 随机准确率：正确 146/488，随机准确率 0.299
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 154/488，随机准确率 0.316
# 准确率计算：正确 221/488，准确率 0.453
# 随机准确率：正确 130/488，随机准确率 0.266
# 准确率计算：正确 211/488，准确率 0.432
# 随机准确率：正确 161/488，随机准确率 0.330
# 准确率计算：正确 222/488，准确率 0.455
# 随机准确率：正确 145/488，随机准确率 0.297
# 准确率计算：正确 231/488，准确率 0.473
# 随机准确率：正确 129/488，随机准确率 0.264
# 准确率计算：正确 226/488，准确率 0.463
# 随机准确率：正确 137/488，随机准确率 0.281
# 准确率计算：正确 204/488，准确率 0.418
# 随机准确率：正确 134/488，随机准确率 0.275
# 准确率计算：正确 236/488，准确率 0.484
# 随机准确率：正确 160/488，随机准确率 0.328
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 146/488，随机准确率 0.299
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 147/488，随机准确率 0.301
# 准确率计算：正确 236/488，准确率 0.484
# 随机准确率：正确 164/488，随机准确率 0.336
# 准确率计算：正确 222/488，准确率 0.455
# 随机准确率：正确 148/488，随机准确率 0.303
# 准确率计算：正确 231/488，准确率 0.473
# 随机准确率：正确 152/488，随机准确率 0.311
# 准确率计算：正确 232/488，准确率 0.475
# 随机准确率：正确 141/488，随机准确率 0.289
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 150/488，随机准确率 0.307
# 准确率计算：正确 204/488，准确率 0.418
# 随机准确率：正确 145/488，随机准确率 0.297
# 准确率计算：正确 220/488，准确率 0.451
# 随机准确率：正确 139/488，随机准确率 0.285
# 准确率计算：正确 216/488，准确率 0.443
# 随机准确率：正确 141/488，随机准确率 0.289
# 准确率计算：正确 222/488，准确率 0.455
# 随机准确率：正确 156/488，随机准确率 0.320
# 准确率计算：正确 228/488，准确率 0.467
# 随机准确率：正确 127/488，随机准确率 0.260
# 准确率计算：正确 235/488，准确率 0.482
# 随机准确率：正确 145/488，随机准确率 0.297
# 准确率计算：正确 208/488，准确率 0.426
# 随机准确率：正确 138/488，随机准确率 0.283
# 准确率计算：正确 231/488，准确率 0.473
# 随机准确率：正确 157/488，随机准确率 0.322
# 准确率计算：正确 213/488，准确率 0.436
# 随机准确率：正确 168/488，随机准确率 0.344
# 准确率计算：正确 225/488，准确率 0.461
# 随机准确率：正确 147/488，随机准确率 0.301
# 保存类别 'Economy & Business' 的准确率结果到 e:\VS code project\Cross Attention for Combo\Classification_ClassAccuracy\accuracy_results\Economy & Business_accuracy_different_model.csv
